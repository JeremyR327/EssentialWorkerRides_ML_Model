# %%
import googlemaps
from datetime import datetime
import pandas as pd
import numpy as np
import requests
import lxml.html as lh

# %%
my_key = 'AIzaSyAjoUqdDIqbFHLb5Kw-QN_Yguktghgro8M'

# %%
gmaps = googlemaps.Client(key=my_key)

# %%
geocode_result = gmaps.geocode('Jerome Av / Bainbridge Av')
# Out:
# ---------------------------------------------------------------------------
# ApiError                                  Traceback (most recent call last)
# <ipython-input-19-566d1dc83efc> in <module>
# ----> 1 geocode_result = gmaps.geocode('Jerome Av / Bainbridge Av')
#
# //anaconda3/lib/python3.7/site-packages/googlemaps/client.py in wrapper(*args, **kwargs)
#     416     def wrapper(*args, **kwargs):
#     417         args[0]._extra_params = kwargs.pop("extra_params", None)
# --> 418         result = func(*args, **kwargs)
#     419         try:
#     420             del args[0]._extra_params
#
# //anaconda3/lib/python3.7/site-packages/googlemaps/geocoding.py in geocode(client, address, components, bounds, region, language)
#      66         params["language"] = language
#      67
# ---> 68     return client._request("/maps/api/geocode/json", params).get("results", [])
#      69
#      70
#
# //anaconda3/lib/python3.7/site-packages/googlemaps/client.py in _request(self, url, params, first_request_time, retry_counter, base_url, accepts_clientid, extract_body, requests_kwargs, post_json)
#     311                 result = extract_body(response)
#     312             else:
# --> 313                 result = self._get_body(response)
#     314             self.sent_times.append(time.time())
#     315             return result
#
# //anaconda3/lib/python3.7/site-packages/googlemaps/client.py in _get_body(self, response)
#     341
#     342         raise googlemaps.exceptions.ApiError(api_status,
# --> 343                                              body.get("error_message"))
#     344
#     345     def _generate_auth_url(self, path, params, accepts_clientid):
#
# ApiError: REQUEST_DENIED (You must enable Billing on the Google Cloud Project at https://console.cloud.google.com/project/_/billing/enable Learn more at https://developers.google.com/maps/gmp-get-started)

# %%
url='https://new.mta.info/coronavirus/bx99stops'
#Create a handle, page, to handle the contents of the website
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//tr')

# %%
tr_elements = doc.xpath('//tr')
#Create empty list
col=[]
i=0
#For each row, store each first element (header) and an empty list
for t in tr_elements[0]:
    i+=1
    name=t.text_content()
    print('%d:"%s"'%(i,name))
    col.append((name,[]))
# Out:
# 1:"﻿Stop Number
# "
# 2:"On Street
# "
# 3:"At Street
# "
# 4:"Corner
# "
# 5:"Destination
# "

# %%
for j in range(1,len(tr_elements)):
    #T is our j'th row
    T=tr_elements[j]
    
    
    #i is the index of our column
    i=0
    
    #Iterate through each element of the row
    for t in T.iterchildren():
        data=t.text_content() 
        #Check if row is empty
        if i>0:
        #Convert any numerical value to integers
            try:
                data=int(data)
            except:
                pass
        #Append the data to the empty list of the i'th column
        col[i][1].append(data)
        #Increment i for the next column
        i+=1

# %%
Dict={title:column for (title,column) in col}
df=pd.DataFrame(Dict)

# %%
for col in df.columns:
    df[col] = df[col].apply(lambda x: x.replace('\n',''))

# %%
df.columns = [x.replace('\n','') for x in df.columns]

# %%
df = df.iloc[:35]

# %%
df['Cross Street'] = df['On Street'] + ' / ' + df['At Street']

# %%
df
# Out:
#    ﻿Stop Number        On Street         At Street Corner   Destination  \
# 0             1        Jerome Av     Bainbridge Av    Far  West Village
# 1             2        Jerome Av  E Mosholu Pkwy N    Far  West Village
# 2             3        Jerome Av          E 205 St   Near  West Village
# 3             4        Jerome Av  W Kingsbridge Rd   Near  West Village
# 4             5        Jerome Av      W Fordham Rd   Near  West Village
# 5             6        Jerome Av          W 183 St   Near  West Village
# 6             7        Jerome Av     W Burnside Av   Near  West Village
# 7             8  Grand Concourse          E 177 St    Far  West Village
# 8             9  Grand Concourse         Morris Av    Far  West Village
# 9            10  Grand Concourse      E Mt Eden Av    Far  West Village
# 10           11  Grand Concourse          E 170 St    Far  West Village
# 11           12  Grand Concourse          E 167 St    Far  West Village
# 12           13  Grand Concourse          E 161 St    Far  West Village
# 13           14  Grand Concourse          E 149 St    Far  West Village
# 14           15  Grand Concourse          E 138 St   Near  West Village
# 15           16             3 Av          E 138 St   Near  West Village
# 16           17             2 Av          E 125 St    Far  West Village
# 17           18             2 Av          E 111 St    Far  West Village
# 18           19             2 Av           E 96 St    Far  West Village
# 19           20             2 Av           E 86 St   Near  West Village
# 20           21             2 Av           E 72 St    Far  West Village
# 21           22             2 Av           E 61 St    Far  West Village
# 22           23          E 57 St      Lexington Av    Far  West Village
# 23           24          W 57 St              5 Av    Far  West Village
# 24           25          W 57 St              7 Av    Far  West Village
# 25           26          W 57 St              9 Av    Far  West Village
# 26           27            11 Av           W 57 St    Far  West Village
# 27           28            11 Av           W 50 St   Near  West Village
# 28           29            11 Av           W 42 St    Far  West Village
# 29           30            11 Av           W 34 St    Far  West Village
# 30           31            11 Av           W 23 St    Far  West Village
# 31           32          W 14 St              8 Av    Far  West Village
# 32           33           7 Av S           W 10 St    Far  West Village
# 33           34        Varick St       Clarkson St    Far  West Village
# 34           35    Washington St      W Houston St    Far  West Village
#
#                       Cross Street
# 0        Jerome Av / Bainbridge Av
# 1     Jerome Av / E Mosholu Pkwy N
# 2             Jerome Av / E 205 St
# 3     Jerome Av / W Kingsbridge Rd
# 4         Jerome Av / W Fordham Rd
# 5             Jerome Av / W 183 St
# 6        Jerome Av / W Burnside Av
# 7       Grand Concourse / E 177 St
# 8      Grand Concourse / Morris Av
# 9   Grand Concourse / E Mt Eden Av
# 10      Grand Concourse / E 170 St
# 11      Grand Concourse / E 167 St
# 12      Grand Concourse / E 161 St
# 13      Grand Concourse / E 149 St
# 14      Grand Concourse / E 138 St
# 15                 3 Av / E 138 St
# 16                 2 Av / E 125 St
# 17                 2 Av / E 111 St
# 18                  2 Av / E 96 St
# 19                  2 Av / E 86 St
# 20                  2 Av / E 72 St
# 21                  2 Av / E 61 St
# 22          E 57 St / Lexington Av
# 23                  W 57 St / 5 Av
# 24                  W 57 St / 7 Av
# 25                  W 57 St / 9 Av
# 26                 11 Av / W 57 St
# 27                 11 Av / W 50 St
# 28                 11 Av / W 42 St
# 29                 11 Av / W 34 St
# 30                 11 Av / W 23 St
# 31                  W 14 St / 8 Av
# 32                7 Av S / W 10 St
# 33         Varick St / Clarkson St
# 34    Washington St / W Houston St
